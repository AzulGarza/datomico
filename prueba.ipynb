# %%
import sys
import pandas as pd
from IPython.display import HTML, display


# %matplotlib inline

# %%
from datomico.structured import *

# %%
sys.executable
# Out:
# '/home/samuel/anaconda3/envs/datomico/bin/python'

# %%
# %pwd
# Out:
# '/home/samuel/Documents/datomico'

# %%
# !ls
# Out:
# data  prueba.ipynb  README.md

# %%
PATH = 'data/'

# %%
data_names = ['test', 'oil', 'holidays_events', 'stores','transactions', 'items'] # Falta train

# %%
data = [pd.read_csv(f'{PATH}{fname}.csv', low_memory=False) for fname in data_names]

# %%
for d in data: display(d.head())
# Out:
#           id        date  store_nbr  item_nbr  onpromotion
# 0  125497040  2017-08-16          1     96995        False
# 1  125497041  2017-08-16          1     99197        False
# 2  125497042  2017-08-16          1    103501        False
# 3  125497043  2017-08-16          1    103520        False
# 4  125497044  2017-08-16          1    103665        False
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# ...

# %%
sys.path
# Out:
# ['',
#  '/home/samuel/Documents/datomico',
#  '/home/samuel/anaconda3/envs/datomico/lib/python37.zip',
#  '/home/samuel/anaconda3/envs/datomico/lib/python3.7',
#  '/home/samuel/anaconda3/envs/datomico/lib/python3.7/lib-dynload',
#  '/home/samuel/anaconda3/envs/datomico/lib/python3.7/site-packages',
#  '/home/samuel/anaconda3/envs/datomico/lib/python3.7/site-packages/IPython/extensions',
#  '/home/samuel/.ipython']

# %%
test, oil, holidays_events, stores, transactions, items = data

# %%
len(test)
# Out:
# 3370464

# %%
add_datepart(test, "date", drop=False)

# %%
display(test.head())
# Out:
#           id       date  store_nbr  item_nbr  onpromotion  Year  Month  Week  \
# 0  125497040 2017-08-16          1     96995        False  2017      8    33
# 1  125497041 2017-08-16          1     99197        False  2017      8    33
# 2  125497042 2017-08-16          1    103501        False  2017      8    33
# 3  125497043 2017-08-16          1    103520        False  2017      8    33
# 4  125497044 2017-08-16          1    103665        False  2017      8    33
#
#    Day  Dayofweek  Dayofyear  Is_month_end  Is_month_start  Is_quarter_end  \
# 0   16          2        228         False           False           False
# 1   16          2        228         False           False           False
# 2   16          2        228         False           False           False
# 3   16          2        228         False           False           False
# 4   16          2        228         False           False           False
#
# ...
